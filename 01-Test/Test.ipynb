# %%
import pandas as pd

# %%
print('Hello')
# Out:
# Hello

# %%
print("I don't know how to push and commit this on to github")
import numpy as np
# Out:
# I don't know how to push and commit this on to github
